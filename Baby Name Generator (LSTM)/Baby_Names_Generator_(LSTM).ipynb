# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install unidecode
# Out:
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/9e/25/723487ca2a52ebcee88a34d7d1f5a4b80b793f179ee0f62d5371938dfa01/Unidecode-1.2.0-py2.py3-none-any.whl (241kB)
#      |████████████████████████████████| 245kB 30.7MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.2.0

# %%
# importing libraries:

import torch
import torch.nn as nn 
import random
import sys
import string
from unidecode import unidecode

# %%
# device configuration 
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
file = unidecode(open('/content/drive/MyDrive/Colab Notebooks/names.txt').read())

# %%
# Getting characters from string.printable

all_characters = string.printable
n_characters = len(all_characters)

print(f"{all_characters}")
print(f"Total number of characters: {n_characters}")
# Out:
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Total number of characters: 100

# %%
# creating the RNN class 
class RNN(nn.Module):
  def __init__(self, input_size, hidden_size, num_layers, output_size):
    super(RNN, self).__init__()

    self.hidden_size = hidden_size
    self.num_layers = num_layers

    # creating the embedding:
    self.embed = nn.Embedding(input_size, hidden_size)
    self.lstm = nn.LSTM(hidden_size, hidden_size, num_layers, batch_first=True)
    self.fc = nn.Linear(hidden_size, output_size)
  
  def forward(self, x, hidden, cell):
    out = self.embed(x)
    out, (hidden, cell) = self.lstm(out.unsqueeze(1), (hidden, cell))
    out = self.fc(out.reshape(out.shape[0], -1))

    return out, (hidden, cell)
  
  # initializing the hidden states and cell states:
  def init_hidden(self, batch_size):
    hidden = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)
    cell = torch.zeros(self.num_layers, batch_size, self.hidden_size).to(device)

    return (hidden, cell)

# %%
# Generator Class to generate names
class Generator():
  def __init__(self):
    self.chunk_len = 250
    self.num_epochs = 5000
    self.batch_size = 1
    self.print_every = 50
    self.hidden_size = 256
    self.num_layers = 2
    self.lr = 0.003

  # taking a character and mapping it to a tensor/vector
  def char_tensor(self, string):
    tensor = torch.zeros(len(string)).long()
    for c in range(len(string)):
      tensor[c] = all_characters.index(string[c])

    return tensor
  
  def get_random_batch(self):
    start_index = random.randint(0, len(file) - self.chunk_len)
    end_index = start_index + self.chunk_len + 1

    text_str = file[start_index:end_index]
    text_input = torch.zeros(self.batch_size, self.chunk_len)
    text_target = torch.zeros(self.batch_size, self.chunk_len)

    for i in range(self.batch_size):
      text_input[i, :] = self.char_tensor(text_str[:-1])
      text_target[i, :] = self.char_tensor(text_str[1:])

    return text_input.long(), text_target.long()

  # generate some names for us
  def generate(self, initial_string='Ab', prediction_length=100, temperature=0.85):
    hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)
    initial_input = self.char_tensor(initial_string)
    predicted = initial_string

    for p in range(len(initial_string) - 1):
      _, (hidden, cell) = self.rnn(initial_input[p].view(1).to(device), hidden, cell)

    last_char = initial_input[-1]

    for p in range(prediction_length):
      output, (hidden, cell) = self.rnn(last_char.view(1).to(device), hidden, cell)
      output_dist = output.data.view(-1).div(temperature).exp()
      top_char = torch.multinomial(output_dist, 1)[0]
      predicted_char = all_characters[top_char]
      predicted += predicted_char
      last_char = self.char_tensor(predicted_char)

    return predicted


    # training loop
  def train(self):
    self.rnn = RNN(n_characters, self.hidden_size, self.num_layers, n_characters).to(device)

    optimizer = torch.optim.Adam(self.rnn.parameters(), lr=self.lr)
    criterion = nn.CrossEntropyLoss()
    print("=> Starting Training")

    for epoch in range(self.num_epochs):
      input, target = self.get_random_batch()
      hidden, cell = self.rnn.init_hidden(batch_size=self.batch_size)
      self.rnn.zero_grad()
      loss=0
      input = input.to(device)
      target = target.to(device)

      # sending characters to RNN:
      for c in range(self.chunk_len):
        output, (hidden, cell) = self.rnn(input[:, c], hidden, cell)
        loss += criterion(output, target[:, c])

      loss.backward()
      optimizer.step()
      loss = loss.item() / self.chunk_len

      if epoch % self.print_every == 0:
        print(f"Loss: {loss}")
        print(self.generate())

# %%
gennames = Generator()

# %%
gennames.train()
# Out:
# => Starting Training
# Loss: 4.6122607421875
# AbEWTLt@qk|~#|:ih1|V1y"]Q\pXbF&d4PT`>#X2C5*WA.aDn}_yUH~]=Xe@fj@2Y>iMwmv`i*H;r|Bx	d&+on!a6 ]9>5Zbcy`u
# Loss: 2.34671923828125
# Abatay
# Eonon
# Meollo
# Ryio
# Karan
# Elhd
# Jelia
# Lecderly
# Rareron
# Jerih
# Van
# yniniie
# Larfona
# Jene
# Hisha
# Ro
# Nor
# Loss: 2.556522216796875
# Abnyles
# Mary
# Conne
# Laesa
# Nonha
# Masaotha
# Bidie
# Awrili
# Friamanlay
# Rin
# Diolar
# Sarryla
# Samis
# Cinta
# Merian
#
# Loss: 2.068472900390625
# Aberal
# Avinna
# Jadis
# Meiga
# Weend
# Arince
# Lereste
# Dronson
# Kusina
# Chrissice
# Annie
# Rerane
# Marlan
# Leris
# Rish
# Loss: 2.130690673828125
# Abrio
# Jadima
# Braan
# Maiania
# Yaani
# Qedens
# Chra
# Mendeelina
# Heann
# Jeinne
# Albarlon
# Keles
# Jatlee
# Rissaya
# Pav
# Loss: 1.9506175537109376
# Abarly
# Rosay
# Jimton
# Man
# Erlick
# Kariel
# Charly
# Ramace
# Damore
# Mary
# Rory
# Jullyn
# Laine
# Thenise
# Broley
# Jordy
# Loss: 1.9006700439453126
# Abie
# Larman
# Sheri
# Reberl
# Matheril
# Twance
# Adrento
# Camvere
# Catyan
# Leonandy
# Ylaxer
# Epor
# Antrill
# Ji
# Clane
#
# Loss: 1.8486295166015625
# Abrien
# Ailas
# Kend
# Joruell
# Thery
# Vika
# Rinal
# Rostay
# Praw
# Troy
# Patryar
# Treann
# Jumis
# Lorlie
# Lynnall
# Tonas
#
# Loss: 1.8844600830078124
# Abig
# Karle
# Gilla
# Ronny
# Faralis
# Conje
# Sefery
# Marteni
# Frester
# Jennia
# Syley
# Joyah
# Douglig
# Mariss
# Melisan
#
# Loss: 1.6078538818359376
# Aba
# Marrin
# Lysa
# Cari
# Abbert
# Drasie
# Lou
# Jeeson
# Stelly
# Danny
# Laoren
# Edsan
# Hania
# Paula
# Lenna
# Nathina
# Ber
#
# Loss: 1.760240478515625
# Aby
# Petquelo
# De
# Malone
# Bevin
# Emnia
# Pamefian
# Tama
# Samaine
# Brannest
# Gravin
# Karlon
# Carlen
# Cary
# Mara
# Kery
#
# Loss: 1.66514990234375
# Abison
# Lorgue
# Bernaed
# Bellip
# Kenne
# Chinsesa
# Dean
# Alysanne
# Xaurien
# Dasbie
# Siston
# Marsa
# Brente
# Terryle
# A
# Loss: 2.033654296875
# Abrences
# Rhulene
# Alan
# Tracin
# Lestine
# Jaco
# Allanie
# Isa
# Urina
# Jerina
# Mita
# Kalene
# Rosalle
# Kristy
# Kalinela
# Loss: 1.687844482421875
# Abevah
# Phurtan
# Shenton
# Donnie
# Dory
# Charleo
# Brander
# Gerjami
# Ellia
# Trolg
# Marzell
# Carllif
# Larol
# Elisha
# Do
# Loss: 1.7563951416015624
# Aben
# Marlie
# Sharlalie
# Micharle
# Susas
# Donia
# Ann
# Mariallie
# Derriell
# Micharla
# Anthan
# Charlin
# Betry
# Dinnet
# Loss: 2.0151943359375
# Abello
# Suzan
# Sammin
# Kenni
# Boglines
# Ann
# Mari
# Charda
# Cayne
# Anne
# Scylor
# Richagha
# Rocey
# Jaybara
# Pharatha
# Z
# Loss: 1.8974066162109375
# Abrin
# Sachy
# Larrif
# Stefer
# Brittan
# Simon
# Sabrina
# Elliffert
# Marik
# Pathleel
# Roseph
# Renice
# Sheathan
# Marcil
# Loss: 1.5144033203125
# Abby
# Chanles
# Nelly
# irson
# Wilina
# Amina
# Gillie
# Arnell
# Glam
# Gronces
# Joshall
# Shello
# Hayley
# Hoy
# John
# Vinthe
# Loss: 1.5297940673828125
# Abbie
# Alvah
# Nathan
# Racia
# Pedea
# Jenniffry
# Slebeva
# Shelanie
# Tyra
# Alyna
# Vamer
# Manuel
# Olena
# Alariel
# Breda
#
# Loss: 1.7889703369140626
# Abei
# Sara
# Alia
# Nenora
# Urisie
# Horly
# Kayler
# Shelby
# Villy
# Ariah
# Tiaman
# Ceniel
# Feline
# Pri
# Auina
# Sonne
# Lemi
# Loss: 1.55109619140625
# Abin
# Triston
# Tem
# Temmy
# Sampar
# Andria
# Austin
# Briddy
# Andera
# Ara
# Allon
# Alman
# Velsence
# Roberto
# Reannette
# A
# Loss: 1.5528544921875
# Ablen
# Bill
# Michel
# Megra
# Raliamha
# Jence
# Edwand
# Jerad
# Grold
# Dustin
# Miki
# Luy
# Melonie
# Kellie
# Bercie
# Enita
#
# Loss: 1.5647559814453125
# Abra
# Desmand
# Elia
# Kathrine
# Erinet
# Deanne
# Davey
# Elizey
# Lauren
# Nighan
# Stephan
# Sterryd
# Chante
# Phewdy
# Joni
# Loss: 1.7686632080078124
# Abigadie
# Abigabela
# Alyza
# Bracy
# Eleana
# Elana
# Danell
# Felice
# Lena
# Ellisa
# Delbert
# Danital
# Estella
# Feancie
#
# Loss: 1.4690552978515625
# Aby
# Angel
# Halyson
# Theonah
# Misti
# Pail
# Rolfne
# Stephani
# Sola
# Theena
# Sherry
# Ryann
# Tamara
# Sancel
# Tim
# Shania
# Loss: 1.378162841796875
# Abby
# Astira
# Ana
# Alexayssa
# Anaisha
# Chrystin
# Chanca
# Kasey
# Chortin
# Kimbert
# Laures
# Wonda
# Kentie
# Kathi
# Mari
# Loss: 1.3742633056640625
# Abatha
# Asika
# Ann
# Adelina
# Alis
# Bandal
# Frank
# Fait
# Eddon
# Esther
# Franki
# Elda
# Evandy
# Erna
# Lewis
# Luka
# Mela
# K
# Loss: 1.4610958251953126
# Abekala
# Betty
# Regina
# Guadise
# Gederice
# Salla
# Yvette
# Clida
# Kim
# Pamella
# Zaklys
# Lucille
# Makena
# Veerna
# Vlor
# Loss: 1.562068359375
# Abel
# Alexandra
# Elvert
# Ermand
# Eogan
# Edube
# Pailey
# Abbie
# Alfredia
# Ayun
# Alfry
# Ashlee
# Alvin
# Theresa
# Thurree
# Loss: 1.3621510009765625
# Abra
# Alexis
# Pruck
# Priace
# Silene
# Summan
# Curtie
# Clatesse
# Claro
# Denny
# Debiarson
# Guaduem
# Guiden
# Jannuel
# Ja
# Loss: 1.2818548583984375
# Abia
# Alexandra
# Armandr
# Andrew
# Angeline
# Destan
# Fernando
# Fali
# Hreston
# Juliettie
# Jose
# Janette
# Janice
# Jose
# Loss: 1.8702802734375
# Abrtie
# Chantel
# Caril
# Chlifford
# Mariana
# Genises
# Carmen
# Christindo
# Christos
# Esthel
# Cistin
# Damien
# Grent
# G
# Loss: 1.5217109375
# Abeth
# Anniela
# Beth
# Desti
# Frank
# Donnie
# Jariana
# Jeanne
# Gregg
# Daidal
# Mauree
# Cristopher
# Estefan
# Clifford
# D
# Loss: 1.4785977783203126
# Abrette
# Armely
# Asi
# Billie
# Divah
# Edise
# Estelle
# Eaver
# Eddalynn
# Elean
# Eddie
# Esseb
# Jacqueline
# Hollis
# Jo
# Ja
# Loss: 1.631420654296875
# Aben
# Adel
# Anton
# Bejein
# Christa
# Lara
# Bruce
# Charlie
# Marie
# Harrity
# Harold
# Stefus
# Stephan
# Braet
# Brandy
# Dav
# Loss: 1.8396722412109374
# Abyn
# Artian
# Brooke
# Brooke
# Carmel
# Celinia
# Karen
# Katharine
# Titana
# Ketis
# Manuel
# Madeline
# Nathan
# Ronell
# So
# Loss: 1.36482421875
# Abreyan
# Darren
# Derren
# Dorother
# Edinia
# Eliah
# Elliana
# Ember
# Chrance
# Kristin
# Kaylee
# Lawron
# Lenai
# Maci
# Mar
# Loss: 1.285592041015625
# Abenahar
# Crissa
# Cecilia
# Carolin
# Cory
# Allier
# Dean
# Drigia
# Elisabeth
# Elma
# Kayla
# Marian
# Lary
# Lucas
# Marcel
#
# Loss: 1.3837608642578125
# Abethani
# Anissa
# Baron
# Bernon
# Beatriss
# Christine
# Jaclyn
# Michelle
# Regina
# Tere
# Constance
# Ivonne
# Janetha
# J
# Loss: 1.1747457275390625
# Abighi
# Amelia
# Annabeth
# Decolas
# Emma
# Elliot
# Ermen
# Ether
# Hannah
# Zianna
# Ellean
# Emsley
# Emmie
# Damon
# Ern
# Emm
# Loss: 1.5788013916015624
# Abobi
# Aryanna
# Alojeveriah
# Adan
# Judolyn
# Theodore
# Trice
# Emma
# Laronia
# Lacey
# Leetha
# Loretha
# Mason
# Marinele
# Loss: 1.6686046142578126
# Abekah
# Bernatt
# Shaona
# Sam
# Charlis
# Coley
# Charlen
# Christopher
# John
# Jeanne
# Loual
# Mirgura
# Audrey
# Bradley
# C
# Loss: 1.391930419921875
# Abigoin
# Allynette
# Anton
# Allenne
# Boby
# Cherrie
# Brenda
# Dee
# Edson
# Esther
# Geraldo
# Jazmine
# Jean
# Kathrinell
# J
# Loss: 1.5096416015625
# Abeka
# Analisa
# Brandie
# Billy
# Alexandra
# Bennie
# Shawnarta
# Shelby
# Shelby
# Steve
# Aria
# Adrienne
# Felinda
# Brean
# Loss: 1.512286865234375
# Aben
# Anek
# Abora
# Anne
# Anna
# Jeannette
# Jenna
# Shanna
# Stephan
# Shayna
# Teagan
# Angelina
# Annison
# Benorroe
# Fredi
# Loss: 1.38168310546875
# Aby
# Bethany
# Benita
# Carriet
# Candice
# Callie
# Carla
# Cwin
# Cellen
# Colton
# Dennis
# Donnie
# Dorian
# Elizabeth
# Flor
# Loss: 1.5071959228515626
# Abrina
# Afred
# Alfred
# Ariana
# Ani
# Arsumie
# Alanise
# Annie
# Angela
# Anne
# Amalia
# Ben
# Brett
# Alvin
# Yasmid
# Steffre
# Loss: 1.2267586669921875
# Abina
# Christipher
# Jaylen
# Alizer
# Albert
# Yarshard
# Anie
# Ashleigh
# Andrea
# Yonda
# Cheri
# Chelsia
# Claudia
# Demir
# Loss: 1.221726806640625
# Abel
# Martha
# Mary
# Mackenzie
# Petez
# Olia
# Orvin
# Madison
# Pikaylin
# Nahsey
# Mary
# Maura
# Melody
# Miranda
# Marisol
#
# Loss: 1.452560546875
# Abbiel
# Augustine
# Annie
# Emma
# Elma
# Jeremy
# Joshiah
# Jasmine
# Janise
# Jonna
# Hollie
# Kelli
# Kayla
# Keira
# Kiyana
# K
# Loss: 1.2567154541015626
# Abel
# Alvino
# Adrienne
# Arnell
# Angeli
# Adrien
# Agtic
# Bredgau
# Bettre
# Claire
# Dorothy
# Dylan
# Deene
# Dennene
# Dali
# Loss: 1.077526611328125
# Abrenca
# Annie
# Annaika
# Antoinette
# Alekan
# Willie
# Staci
# Shyanna
# Shawn
# Shawn
# Tywan
# Terray
# Montem
# Morry
# Nia
# Loss: 1.2252061767578124
# Abnie
# Bryann
# Bridgette
# Benna
# Brina
# Dale
# Deborah
# Dorie
# Earna
# Elsie
# Francisca
# Glen
# Heath
# Gabriel
# Denny
# G
# Loss: 1.323712646484375
# Aboquie
# Brett
# Alice
# Andres
# Albert
# Cliffo
# Domenick
# Eva
# Fridget
# Greg
# Richardo
# Hander
# Geno
# Donet
# Fredrick
# Loss: 1.848228271484375
# Abetha
# Barbara
# Ailyn
# Ann
# Arianna
# Annette
# Cathy
# Colly
# Curtis
# Donald
# Denite
# Dorothy
# Emmet
# Ellen
# Erin
# Gen
# Loss: 1.54091748046875
# Abie
# Amy
# Amario
# Allessa
# Bruce
# Benjamin
# Jimmy
# Larell
# Brandes
# Wilford
# Madelyn
# John
# Sonuela
# Willie
# Steve
#
# Loss: 2.108711669921875
# Abikahra
# Viola
# Viola
# Emory
# Katherine
# Karin
# Katazielle
# Kristal
# Lysia
# Meghan
# Marita
# Maria
# Maria
# Majel
# Ma
# Loss: 1.053263427734375
# Abin
# Charley
# Colter
# Brant
# Dara
# Cecelia
# Desiree
# Delores
# Daryley
# Dane
# Desiree
# Ette
# Evette
# Eric
# Faith
# Fre
# Loss: 1.0614798583984375
# Abon
# Brenda
# Camyle
# Carolynn
# Cathy
# Catherine
# Caris
# Chloe
# Cristie
# Donnie
# Elsie
# Everett
# Erich
# Jane
# Kendi
#
# Loss: 1.351752685546875
# Abby
# Angela
# Ana
# Billinda
# Benny
# Barbara
# Deja
# Deandre
# Delin
# Donell
# Eleanor
# Emiliano
# Faye
# Glenna
# Garis
# Gr
# Loss: 1.236845703125
# Aberto
# Arthur
# Albert
# Wilse
# Annie
# Anna
# Barbara
# Brianna
# Bradise
# Eric
# Bonity
# Holly
# John
# Bryan
# Merly
# Brean
# Loss: 1.2909232177734375
# Abrahatha
# AlAka
# Brandy
# Brenda
# CAkhae
# Henriet
# Ivy
# IEIIIIHIlen
# Ida
# Albert
# Agustan
# Adormian
# Armantha
# Anit
# Loss: 1.109915771484375
# Aberstina
# Alyssa
# Alonzo
# Adrianne
# Alex
# Andrea
# Angelia
# Alexis
# Arianna
# Candi
# Carla
# Caroline
# Coris
# Dolores
# Loss: 1.233198486328125
# Abel
# Angelita
# Angelo
# Adamario
# Yssachel
# Cornelique
# Craig
# David
# Edward
# Emme
# Elia
# Emiley
# Eileen
# Frank
# Gar
# Loss: 1.85326025390625
# Abel
# Shelda
# Chelsea
# Desira
# Estella
# George
# James
# Kathryn
# Kyle
# Kendra
# Kirby
# Koli
# Kyle
# Kelley
# Kirstyn
# Kri
# Loss: 1.54274755859375
# Abettia
# Alexis
# Asha
# Anastadia
# Anne
# Angelica
# Anne
# Alyssa
# Amos
# Aubri
# Alexa
# Alice
# Aliya
# Alexis
# Anahira
# An
# Loss: 1.2942183837890624
# Abel
# Biritte
# Amelia
# Abbygail
# Angelinda
# Beanne
# Beatrice
# Bekina
# Cleo
# Dawnn
# Danya
# Delores
# Emmalo
# Eeggie
# E
# Loss: 1.2572840576171875
# Abinne
# Analie
# Ariellia
# Angela
# Alyssa
# Anne
# Alani
# Billie
# Bonnie
# Gianna
# Chetti
# Charlotte
# Nadia
# Rebecka
# Va
# Loss: 1.1161392822265626
# Aby
# Alicia
# Aubray
# Bennie
# Brayl
# Brysta
# Brent
# Evelyn
# Grant
# Heledar
# Jotte
# Josephine
# Jeanine
# Kendall
# Karle
# Loss: 1.310159912109375
# Abelch
# Alvina
# Alicia
# Anaya
# Alicia
# Adrianna
# Ailian
# Ana
# Amelia
# Analee
# Bobbyr
# Breanna
# Carla
# Calah
# Candice
# Loss: 1.2983853759765625
# Abigail
# Abika
# Amis
# Afton
# Caroline
# Chriscilline
# Carissa
# Cathyley
# July
# Clifford
# Betty
# Christina
# Danette
#
# Loss: 1.1671856689453124
# Ably
# Angelita
# Audrey
# Carly
# Chelsey
# Cherie
# Dorothy
# Emma
# Elma
# Edith
# Fate
# Halle
# Geneva
# Fay
# Gabriel
# Helen
#
# Loss: 1.4758126220703125
# Abe
# Ava
# Averey
# Benita
# Cassidy
# Casey
# Cassidy
# Casandra
# Camil
# Danya
# Dalila
# Damiesha
# Erika
# Elsie
# Emily
# Emm
# Loss: 1.1988284912109375
# Abinara
# Antoina
# Bailey
# Ayannah
# Antoinette
# Alexis
# Ameria
# Bernard
# Arek
# Araceli
# Arnolber
# Birkita
# Caroline
# Loss: 1.1897486572265625
# Abtia
# Dessie
# Britt
# Genesise
# Lee
# London
# Ricardo
# Ricky
# Scarla
# Stephanie
# Shaile
# Sandrina
# Shamart
# Thaddee
#
# Loss: 1.6440098876953124
# Abial
# Aubra
# Florence
# Gio
# Harry
# Britnie
# Anne
# Estela
# Lane
# Lorric
# Blanche
# Charlee
# Yudelynn
# Kerey
# Kelli
# Ka
# Loss: 0.9485043334960938
# Abbetha
# Ashida
# Tonya
# Arlene
# Annie
# Byrayla
# Denise
# Dessonia
# Deyanna
# Doris
# Donna
# Francisca
# Gabriana
# Laris
# Loss: 1.1093717041015625
# Abiela
# Alexiah
# Bernie
# Andria
# Aysha
# Anelah
# Andria
# Anaska
# Arelia
# Ami
# Amarie
# Ashlaine
# Amy
# Alea
# Aidricia
# A
# Loss: 1.2474683837890626
# Abriel
# Alfred
# Cruz
# Carley
# Jerome
# Joy
# Joi
# Jamie
# Jonah
# Joey
# John
# Jud
# Jonah
# Nikolas
# Rudolph
# Ronald
# Sue
# Yu
# Loss: 1.304099609375
# Abiana
# Allyson
# Zora
# Anabelle
# Audrine
# Carmelle
# Christine
# Chloe
# Celeste
# Connie
# Della
# Deanna
# Donna
# Denise
# Loss: 1.184989013671875
# Abigaila
# Casey
# Claya
# Cyrice
# Connie
# Connie
# Daniella
# Dan
# Dariel
# Dylan
# Danielle
# Deana
# Davida
# Dereka
# Dian
#
# Loss: 1.064353515625
# Abigian
# Anita
# Ashley
# Alaya
# Ashley
# Averine
# Aretha
# Ashely
# Bennie
# Blanche
# Brittny
# Boyd
# Bryan
# Brenda
# Bruce
# Loss: 1.59010986328125
# Abby
# Ashlene
# Arbella
# Alyssa
# Alberta
# Angelina
# Amssa
# Allain
# Ariyana
# Ashli
# Alena
# Avaris
# Azaia
# Breana
# Aria
# Loss: 1.521829833984375
# Abigail
# Adrie
# Bryanna
# Carrie
# Clarez
# Cindy
# Colle
# Christy
# Eleanor
# Ella
# Elisabeth
# Emanie
# Edgar
# Emily
# Hele
# Loss: 1.197299072265625
# Abrah
# Alysa
# Catherine
# Cessy
# Elieza
# Georgia
# Giovanna
# Roberta
# Sandra
# Julie
# Katrina
# Karl
# Daw
# Danice
# Eddie
# Loss: 1.35526171875
# Abiellard
# Briana
# Cellina
# Christina
# Colina
# Eileen
# Hamera
# Helenia
# Gilliam
# Hanna
# Hailey
# Sara
# Hanah
# Kaymad
# Loss: 1.2144908447265625
# Abona
# Coleen
# Cheris
# Cynsle
# Paola
# Rana
# Sheree
# Colin
# Dorothy
# Mary
# Ryley
# Randell
# Shelda
# Tani
# Tanesha
# Vern
# Loss: 1.05578466796875
# Abigi
# Carolyn
# Chesse
# Charisse
# Cristin
# Carla
# Charlene
# Chessie
# Christie
# Corinne
# Cheriss
# Delores
# Donne
# El
# Loss: 1.4117425537109376
# Abellie
# Annette
# Anya
# Anne
# Bonnie
# Doris
# Elizabeth
# Elana
# Faith
# Lorraine
# Kaitlin
# Leanne
# Kamera
# Kayla
# Latr
# Loss: 1.3104287109375
# Abel
# Catelina
# Deiree
# Denisha
# Ebony
# Elyse
# Hazel
# Hope
# Isabel
# Jay
# Jana
# Jessie
# Latasha
# Kazel
# Kairi
# Katie
# K
# Loss: 1.054948486328125
# Abiguer
# Alfred
# Alexus
# Alexandro
# Antonia
# Alysha
# Anthony
# Adriann
# Andrew
# Ander
# Alicia
# Alexia
# Autum
# Anthon
# Loss: 1.4307322998046874
# Abellaha
# Anthonia
# Sharri
# Aida
# Anastaf
# Angelica
# Ariel
# Anne
# Annepria
# Aliana
# Azerine
# Bella
# Brianna
# Barbar
# Loss: 1.072091552734375
# Abpilo
# Antonia
# Alyssa
# Alysia
# Amia
# Alexi
# Aliva
# Alexandria
# Alex
# Anja
# Alannah
# Alyssa
# AsAlex
# Brianna
# Caand
# Loss: 1.0272137451171874
# Abel
# Arun
# Antoinette
# Jaylon
# Michael
# Peggy
# Carlos
# Emily
# Leon
# Frank
# Rocky
# Lenifan
# Andrew
# Jarren
# Joeen
# Do
# Loss: 1.044200927734375
# Abiya
# Ariel
# Ada
# Alvia
# Ashlee
# Amarima
# Audra
# Aida
# Austen
# Andrea
# Belinda
# Booker
# Caralynn
# Cynthia
# Crystal
#
# Loss: 1.1802926025390625
# Abelle
# Alonzo
# Bahliya
# Cayleen
# Cassidy
# Carla
# Chari
# Deannelle
# Elijah
# Geraldine
# Jeannette
# Jocelyne
# Kather
# Loss: 1.3644481201171874
# Abraka
# Ariley
# Alison
# Angela
# Aniah
# Ama
# Bettye
# Annika
# Cheryl
# Christiane
# Cristianne
# Chericy
# Cathy
# Clayton
# Loss: 1.215541748046875
# Abbelyan
# Abigia
# Analeena
# Avis
# Arisa
# Betsy
# Bryana
# Brenni
# Crystal
# Bryenne
# Brandy
# Bruel
# Cannie
# Carie
# Carl
# Loss: 1.2436600341796875
# Abigail
# Torray
# Aubrey
# Crystal
# Darrel
# Eddon
# Everette
# Harson
# Helen
# Josephine
# Johanna
# Josean
# Josaly
# Matia
# Loss: 1.0108758544921874
# Abdiel
# Ariel
# Aryannah
# Ashlin
# Alfred
# Ayannah
# Addis
# Arnold
# Aren
# Arnoldine
# Aiman
# Amanda
# Ammir
# Adushm
# Aubr
